# %% [markdown]
# # Selenium Tutorial - Lecture Version
#
# This tutorial is accompanying the lecture slides for "Getting data from the Web (Part 2).
#
# **Author**: Eni Mustafaraj
# **Created on:** Sep 10, 2026
#
# **Table of Contents**
#
# 1. [Using `requests` and `BeautifulSoup`](#sec1)
# 2. [Simple use of `seleniumbase`](#sec2)
# 3. [Clicking button with `seleniumbase`](#sec3)
# 4. [Scrolling with `seleniumbase`](#sec4)
# 5. [Your task: Simple parser](#sec5)
# 6. [Handling pagination](#sec6)
# 7. [Your task: Modify parser for mockup page](#sec7)

# %% [markdown]
# <h2 id="sec1">1. Using <em>requests</em> and <em>BeautifulSoup</em></h2>
#
# We will first try to get the content of both our pages using the two libraries we already know.

# %%
import requests
from bs4 import BeautifulSoup

BASE_URL = "https://cs.wellesley.edu/~cs315/scraping"

# %% [markdown]
# We'll write a function that retrieves the pages, given the URL.

# %%
def fetch_page_content(url):
    """Fetches HTML content from a URL and checks status code."""
    response = requests.get(url)

    print(f"URL: {url}")
    print(f"Status Code: {response.status_code}")

    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch page. Status code: {response.status_code}")
        return None

# %% [markdown]
# Let's test that the function works as intended:

# %%
url = f"{BASE_URL}/page1.html"
page = fetch_page_content(url)
print(page)
# Out:
# URL: https://cs.wellesley.edu/~cs315/scraping/page1.html
# Status Code: 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Data Page V1</title>
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#             padding: 8px; }
#         th { background-color: #f2f2f2; }
#     </style>
# </head>
# <body>
#     <h1>Student Grades V1</h1>
#     <table id="grades-table">
#         <thead>
#             <tr>
#                 <th>Student ID</th>
#                 <th>Name</th>
#                 <th>Grade</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td>101</td>
#                 <td>Alice Johnson</td>
#                 <td>A</td>
#             </tr>
#             <tr>
#                 <td>102</td>
#                 <td>Bob Smith</td>
#                 <td>B</td>
#             </tr>
#             <tr>
#                 <td>103</td>
#                 <td>Charlie Brown</td>
#                 <td>A-</td>
#             </tr>
#         </tbody>
#     </table>
# </body>
# </html>

# %% [markdown]
# And now let's write a function that will extract the values of the table:

# %%
def parse_table(html_content):
    """Parses HTML content and returns table rows as a list of tuples."""
    if not html_content:
        return []

    soup = BeautifulSoup(html_content, "html.parser")
    rows = soup.find_all("tr")

    table_data = []
    for row in rows:
        cells = [cell.get_text(strip=True) for cell in row.find_all(["th", "td"])]
        if cells:
            table_data.append(tuple(cells))

    return table_data

# %% [markdown]
# Now let's test this function with the output of the `fetch_page_content`:

# %%
parse_table(page)
# Out:
# [('Student ID', 'Name', 'Grade'),
#  ('101', 'Alice Johnson', 'A'),
#  ('102', 'Bob Smith', 'B'),
#  ('103', 'Charlie Brown', 'A-')]

# %% [markdown]
# Let's now try these two functions with the dynamic page:

# %%
url = f"{BASE_URL}/page2.html"
page = fetch_page_content(url)
print(page)
parse_table(page)
# Out:
# URL: https://cs.wellesley.edu/~cs315/scraping/page2.html
# Status Code: 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Data Page V2</title>
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#             padding: 8px; }
#         th { background-color: #e2e2e2; }
#     </style>
# </head>
# <body>
#     <h1>Student Grades V2</h1>
#
#     <div id="table-container"></div>
#
#     <script src="data.js"></script>
# </body>
# </html>
# []

# %% [markdown]
# **Conclusion:** For the 2nd page, where the table is injected with JS, our code didn't return any rows. In order to get the entire content of the page, we will use Selenium, which opens a broswer and creates the DOM.

# %% [markdown]
# <h2 id="sec2">2. Simple use of <em>seleniumbase</em></h2>
#
# Seleniumbase is a framework built on top of standard Selenium. It does everything that Selenium does but in a better way and with less overhead.
#
# First, let's open the URL on the browser, load the page, then save the rendered content:

# %%
pip install seleniumbase
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seleniumbase in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (4.54.1)
# Requirement already satisfied: pip>=26.2.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (26.2.1)
# Requirement already satisfied: packaging>=26.3 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (26.3)
# Requirement already satisfied: setuptools>=84.0.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (84.0.0)
# Requirement already satisfied: wheel>=0.48.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.48.0)
# Requirement already satisfied: attrs>=26.1.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (26.1.0)
# Requirement already satisfied: certifi>=2026.7.22 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2026.7.22)
# Requirement already satisfied: exceptiongroup>=1.3.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.3.1)
# Requirement already satisfied: websockets>=16.1.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (17.1)
# Requirement already satisfied: filelock>=3.32.6 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.32.6)
# Requirement already satisfied: fasteners>=0.20 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.20)
# Requirement already satisfied: mycdp>=1.4.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.4.0)
# Requirement already satisfied: pynose>=1.5.5 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.5.5)
# Requirement already satisfied: platformdirs>=4.11.8 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (4.11.8)
# Requirement already satisfied: typing-extensions>=4.16.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (4.16.0)
# Requirement already satisfied: sbvirtualdisplay>=1.4.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.4.0)
# Requirement already satisfied: MarkupSafe>=3.0.3 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.6 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.1.6)
# Requirement already satisfied: six>=1.17.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.17.0)
# Requirement already satisfied: parse>=1.22.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.22.1)
# Requirement already satisfied: parse-type>=0.6.6 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.6.6)
# Requirement already satisfied: colorama>=0.4.6 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.4.6)
# Requirement already satisfied: psutil>=7.2.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (7.2.2)
# Requirement already satisfied: pyyaml>=6.0.3 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (6.0.3)
# Requirement already satisfied: pygments>=2.20.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.21.0)
# Requirement already satisfied: pyreadline3>=3.5.4 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.5.6)
# Requirement already satisfied: tabcompleter>=1.4.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.4.1)
# Requirement already satisfied: pdbp>=1.8.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.8.2)
# Requirement already satisfied: idna>=3.19 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.19)
# Requirement already satisfied: charset-normalizer<4,>=3.5.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.5.1)
# Requirement already satisfied: urllib3<3,>=2.7.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.7.0)
# Requirement already satisfied: requests~=2.34.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.34.2)
# Requirement already satisfied: sniffio==1.3.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.3.1)
# Requirement already satisfied: h11==0.16.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.16.0)
# Requirement already satisfied: outcome==1.3.0.post0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.3.0.post0)
# Requirement already satisfied: trio<1,>=0.34.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.34.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.12.2)
# Requirement already satisfied: wsproto~=1.3.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.3.2)
# Requirement already satisfied: websocket-client~=1.9.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.9.2)
# Requirement already satisfied: selenium==4.49.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (4.49.0)
# Requirement already satisfied: cssselect<2,>=1.5.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.5.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.4.0)
# Requirement already satisfied: execnet==2.1.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.1.2)
# Requirement already satisfied: iniconfig==2.3.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.3.0)
# Requirement already satisfied: pluggy==1.6.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.6.0)
# Requirement already satisfied: pytest==9.1.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (9.1.1)
# Requirement already satisfied: pytest-html==4.0.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (4.0.2)
# Requirement already satisfied: pytest-metadata==3.1.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.1.1)
# Requirement already satisfied: pytest-ordering==0.6 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.6)
# Requirement already satisfied: pytest-rerunfailures==16.6.1 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (16.6.1)
# Requirement already satisfied: pytest-xdist==3.8.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (3.8.0)
# Requirement already satisfied: parameterized==0.9.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.9.0)
# Requirement already satisfied: behave==1.2.6 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (1.2.6)
# Requirement already satisfied: soupsieve~=2.9.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.9.2)
# Requirement already satisfied: beautifulsoup4~=4.15.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (4.15.0)
# Requirement already satisfied: pyotp~=2.10.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (2.10.0)
# Requirement already satisfied: markdown-it-py==4.2.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (4.2.0)
# Requirement already satisfied: mdurl==0.1.2 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (0.1.2)
# Requirement already satisfied: rich<16,>=15.0.0 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from seleniumbase) (15.0.0)
# Requirement already satisfied: cffi>=1.14 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from trio<1,>=0.34.0->seleniumbase) (2.1.1)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium==4.49.0->seleniumbase) (1.7.1)
# Requirement already satisfied: pycparser in C:\Users\chick\AppData\Roaming\Python\Python314\site-packages (from cffi>=1.14->trio<1,>=0.34.0->seleniumbase) (3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from seleniumbase import Driver

url = f"{BASE_URL}/page2.html"

with Driver() as driver:
    driver.open(url)
    # this line is here to make sure the table is created before we save the page
    driver.wait_for_element("#grades-table") 
    driver.sleep(5) # sleep so that we can see the browser
    rendered_html = driver.get_page_source()

# %% [markdown]
# Now that we have the rendered HTML, we can use the function from above to parse the HTML.

# %%
data = parse_table(rendered_html)

print(f"Extracted {len(data)} rows:")
for row in data:
    print(row)
# Out:
# Extracted 4 rows:
# ('Student ID', 'Name', 'Grade')
# ('201', 'Diana Prince', 'A+')
# ('202', 'Evan Wright', 'B+')
# ('203', 'Fiona Gallagher', 'A')

# %% [markdown]
# As we can see, through this method we were able to extract the table content from the dynamic page as well.

# %% [markdown]
# <a id="sec3"></a>
#
# ## 3. Clicking buttons with `seleniumbase`
#
# Our [new interactive page](https://cs.wellesley.edu/~cs315/scraping/page3.html) requires us to click a button a few times for all the data to appear. We'll write code to do that. But first, let's look at the HTML source code to find the button:
#
# ```
# <body>
#     <h1>Student Grades (Interactive)</h1>
#
#     <!-- Button to dynamically add more rows -->
#     <button id="add-btn">Add More Students</button>
#
#     <table id="grades-table">
#         <thead>
# ```

# %% [markdown]
# First we will see what happens if we click once:

# %%
newURL = "https://cs.wellesley.edu/~cs315/scraping/page3.html"

with Driver() as driver:
    driver.open(newURL)
    button_selector = "#add-btn" # the id attribute value for the button
    driver.sleep(2)
    driver.click(button_selector)
    driver.sleep(2)

# %% [markdown]
# Since we wouldn't know in advance how much data there is and how many times we need to click the button, we have to use the functions of the library to understand when the button is disabled.

# %%
with Driver() as driver:
    driver.open(newURL)
    button_selector = "#add-btn" # the id attribute value for the button
    driver.sleep(1)
    while not driver.is_attribute_present(button_selector, "disabled"):
        driver.click(button_selector)
        driver.sleep(1)
        
    # this line needs to be withing the "with ... as ..." block
    rendered_html = driver.get_page_source()

# %% [markdown]
# Let's check that we got all the data by calling the scraping function:

# %%
parse_table(rendered_html)
# Out:
# [('Student ID', 'Name', 'Grade'),
#  ('201', 'Diana Prince', 'A+'),
#  ('202', 'Evan Wright', 'B+'),
#  ('203', 'Fiona Gallagher', 'A'),
#  ('204', 'George Clark', 'B'),
#  ('205', 'Hannah Abbott', 'A-'),
#  ('206', 'Ian Malcolm', 'A'),
#  ('207', 'Julia Roberts', 'B+'),
#  ('208', 'Kevin Bacon', 'A+'),
#  ('209', 'Laura Croft', 'A-')]

# %% [markdown]
# <a id="sec4"></a>
#
# ## 4. Scrolling with `seleniumbase`
#
# Very often, the server will only serve a portion of the page and then load more of the content based on user actions such as scrolling. In fact, most of the web today is based on the concept of "infinite scrolling", new content keeps showing up as you scroll down a page.
#
# Seleniumbase makes it very easy to load the content that is updated dynamically while scrolling.
#
# We will test this with our [infinte_dramas.html](https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html) page (although it's not infinite).
#
# First we will simply get the page to see what's there:

# %%
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html"

with Driver() as driver:
    driver.open(url)
    driver.sleep(1)
    rendered_html = driver.get_page_source()

# %% [markdown]
# Let's write a few lines of BeautifulSoup to see how many dramas are there:

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(rendered_html, "html.parser")
cards = soup.find_all("div", class_="drama-card")
print(len(cards))
# Out:
# 3

# %% [markdown]
# As expected, we got the 3 dramas that show in the page at the start. Now we need to **simulate** scrolling in order to ge the rest of the dramas show up.

# %%
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html"

with Driver() as driver:
    driver.open(url)
    driver.sleep(1)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    driver.sleep(1)
    rendered_html = driver.get_page_source()

# %% [markdown]
# Let's check again how many "drama cards" are received:

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(rendered_html, "html.parser")
cards = soup.find_all("div", class_="drama-card")
print(len(cards))
# Out:
# 6

# %% [markdown]
# We know that there are more than 6 dramas, so we need to have a loop that keeps scrolling. That means that we need to use the scraping capabilities of selenium to check on the fly for the number of drama cards.
#
# **Note:** This example is an excellent one for showing where the looping construct `while` instead of `for` is needed. We have to keep scrolling until we read the end and then break out of the loop.

# %%
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/infinite_dramas.html"

last_count = 0

with Driver() as driver:
    driver.open(url)

    while True:
        # 1. Scroll to the bottom of the page using JavaScript
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        
        # 2. Wait for dynamic JavaScript content to render
        driver.sleep(1.0)
        
        # 3. Check the new count of target elements
        current_count = len(driver.find_elements(".drama-card"))
        print(f"Drama count: {current_count}")
        
        # 4. Exit the loop if no new items loaded after scrolling
        if current_count == last_count:
            print("Reached the bottom of the page.")
            break
            
        last_count = current_count
# Out:
# Drama count: 6
# Drama count: 9
# Drama count: 12
# Drama count: 15
# Drama count: 15
# Reached the bottom of the page.

# %% [markdown]
# <a id="sec5"></a>
#
# ## 5. Your Task: Write a simple parser
#
# Now that we were able to get the list of all dramas from our Top Dramas page, **write a function** similar to function `parse_table` above to exract the following fields from each drama card:
#
# ```
# {rank: "#6",
# title: "Alchemy of Souls",
# year: "2022",
# eps: "20 episodes",
# rating: "8.9",
# type: "Korean Drama",
# synopsis: "A powerful sorceress in a blind woman's body encounters a man from a prestigious family..." }
# ```

# %%
def parse_drama(html_content):
    """Parses HTML content of the top dramas page to extract drama card info"""
    if not html_content:
        return []

    soup = BeautifulSoup(html_content, "html.parser")
    cards = soup.find_all("div", class_="drama-card")

    all_card_info = []
    for card in cards:
        card_info = {}
        card_info["rank"] = card.find("div", class_="rank").get_text(strip=True)
        card_info["title"] = card.find("h2", class_="title").get_text(strip=True)
        card_info["year"] = card.find("div", class_="meta").get_text(strip=True).split()[3]
        card_info["eps"] = card.find("div", class_="meta").get_text(strip=True).split()[4] + " episodes"
        card_info["rating"] = card.find("div", class_="rating").get_text(strip=True).split()[-1]
        card_info["type"] = card.find("div", class_="meta").get_text(strip=True).split()[0] + " " + card.find("div", class_="meta").get_text(strip=True).split()[1]
        card_info["synopsis"] = card.find("div", class_="synopsis").get_text(strip=True)
        all_card_info.append(card_info)
    
    return all_card_info

# %%
drama_card_data = parse_drama(rendered_html)

print(drama_card_data)
# Out:
# [{'rank': '#1', 'title': 'When Life Gives You Tangerines', 'year': '2025,', 'eps': '16 episodes', 'rating': '9.3', 'type': 'Korean Drama', 'synopsis': "A story that resembles a tribute to our parents' tender and still youthful seasons..."}, {'rank': '#2', 'title': 'Twinkling Watermelon', 'year': '2023,', 'eps': '16 episodes', 'rating': '9.2', 'type': 'Korean Drama', 'synopsis': 'In 2023, high school student Eun Gyeol, a CODA with a passion for music, leads a double life...'}, {'rank': '#3', 'title': 'Move to Heaven', 'year': '2021,', 'eps': '10 episodes', 'rating': '9.1', 'type': 'Korean Drama', 'synopsis': "Han Geu Ru is an autistic 20-year-old guy. He works for his father's business Move to Heaven..."}, {'rank': '#4', 'title': 'Hospital Playlist', 'year': '2020,', 'eps': '12 episodes', 'rating': '9.1', 'type': 'Korean Drama', 'synopsis': 'Hospital Playlist tells the story of doctors and nurses working at Yulje Medical Center...'}, {'rank': '#5', 'title': 'Reply 1988', 'year': '2015,', 'eps': '20 episodes', 'rating': '9.0', 'type': 'Korean Drama', 'synopsis': 'Five childhood friends who live in the same Ssangmundong neighborhood rely on each other...'}, {'rank': '#6', 'title': 'Alchemy of Souls', 'year': '2022,', 'eps': '20 episodes', 'rating': '8.9', 'type': 'Korean Drama', 'synopsis': "A powerful sorceress in a blind woman's body encounters a man from a prestigious family..."}]

# %% [markdown]
# Once you have your function, call it on the html content of scrolled page and then save the list of dictionaries into a JSON file, `scraping_results.json`.

# %%
import json

# %%
with open("scraping_results.json", mode="w", encoding="utf-8") as write_file:
    json.dump(drama_card_data, write_file, indent = 2)

# %% [markdown]
# <a id="sec6"></a>
#
# ## 6. Handling Pagination
#
# Our [mockup drama page](https://cs.wellesley.edu/~cs315/scraping/pagination-mockup.html) uses a pagination format, where the URL encodes the index of the page to visit, for example:
#
# ```
# https://cs.wellesley.edu/~cs315/scraping/pagination-mockup.html?page=4
# ```
#
# Below we show some sample code how to handle pagination.

# %%
import math
from seleniumbase import Driver

url = "https://cs.wellesley.edu/~cs315/scraping/pagination-mockup.html"

with Driver() as driver:
    driver.open(url)

    # 1. Extract total results count (e.g., "105 results" -> 105)
    total_text = driver.get_text("p.pull-right") # This will be a string value, 'get text from p tags with the pull-right class'
    total_results = int(total_text.split()[0])

    # 2. Calculate total pages (20 items per page)
    total_pages = math.ceil(total_results / 20)
    print(f"Total results: {total_results} | Total pages: {total_pages}")

    # 4. Loop through each page URL
    for page in range(1, total_pages + 1):
        driver.open(f"{url}?page={page}")
        driver.sleep(1.0)

        # 5. Extract items on the current page
        cards = driver.find_elements(".box")
        print(f"Page {page}: Scraped {len(cards)} dramas")
# Out:
# Total results: 105 | Total pages: 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 25
#      23 cards = driver.find_elements(".box")
#      24 for card in cards:
# ---> 25     card_info = card.get_page_source()
#      26     print(card_info)
#      27 print(f"Page {page}: Scraped {len(cards)} dramas")
#
# AttributeError: 'WebElement' object has no attribute 'get_page_source'

# %% [markdown]
# <a id="sec7"></a>
#
# ## 7. Your Task: Modify Parser
#
# You wrote a `parse_drama` function in Section 5. Update that function to extract the information from the `.box` elements in our paginated mockup drama page. Then calle that function within the loop from Section 6 to scrape the content of each drama and save everything into a JSON file.

# %%
def parse_drama_box(card):
    """Parses HTML content of the pagination dramas page to extract drama card info from class box"""
    if not card:
        return []

    card_info = {}
    card_info["rank"] = card.find("div", class_="ranking pull-right").get_text(strip=True)
    card_info["title"] = card.find("h6", class_="title").get_text(strip=True)
    card_info["year"] = card.find("span", class_="text-muted").get_text(strip=True).split()[3]
    card_info["eps"] = card.find("span", class_="text-muted").get_text(strip=True).split()[4] + " episodes"
    card_info["rating"] = card.find("span", class_="score").get_text(strip=True)
    card_info["type"] = card.find("span", class_="text-muted").get_text(strip=True).split()[0] + " " + card.find("span", class_="text-muted").get_text(strip=True).split()[1]
    card_info["synopsis"] = card.find_all("p")[-1].get_text(strip=True)
    
    return card_info

# %%
url = "https://cs.wellesley.edu/~cs315/scraping/pagination-mockup.html"

with Driver() as driver:
    driver.open(url)

    # 1. Extract total results count (e.g., "105 results" -> 105)
    total_text = driver.get_text("p.pull-right") # This will be a string value, 'get text from p tags with the pull-right class'
    total_results = int(total_text.split()[0])

    # 2. Calculate total pages (20 items per page)
    total_pages = math.ceil(total_results / 20)
    print(f"Total results: {total_results} | Total pages: {total_pages}")

    # 4. Loop through each page URL
    all_pages_info = []
    for page in range(1, total_pages + 1):
        driver.open(f"{url}?page={page}")
        driver.sleep(1.0)
        
        rendered_html = driver.get_page_source()
        soup = BeautifulSoup(rendered_html, "html.parser")
        cards = soup.find_all(class_="box")

        for card in cards:
            card_info = parse_drama_box(card)
            all_pages_info.append(card_info)
# Out:
# Total results: 105 | Total pages: 6

# %%
with open("scraping_results2.json", mode="w", encoding="utf-8") as write_file:
    json.dump(all_pages_info, write_file, indent = 2)
